# %%
import numpy as np
from scipy.stats import multivariate_normal

# Given observations
observations = np.array([[0.6, 0.1], [-0.4, 0.8], [0.2, 0.5], [0.4, -0.1]])

# Initial parameters
pi1 = 0.5
pi2 = 0.5
p1 = 0.3
p2 = 0.7

u1 = np.array([1, 1])  # Updated to 3 dimensions
Sigma1 = np.array([[2, 0.5], [0.5, 2]])  # Updated to 3x3

u2 = np.array([0, 0])  # Updated to 3 dimensions
Sigma2 = np.array([[1.5, 1], [1, 1.5]])  # Updated to 3x3

gauss1 = multivariate_normal.pdf(observations, mean=u1, cov=Sigma1)
gauss2 = multivariate_normal.pdf(observations, mean=u2, cov=Sigma2)
print("Gauss1: ", gauss1)
print("Gauss2: ", gauss2)
# Out:
# Gauss1:  [0.0665753  0.05004889 0.06837452 0.05904699]
# Gauss2:  [0.11961837 0.06819058 0.12958103 0.12450009]
